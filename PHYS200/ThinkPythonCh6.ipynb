# %%
import math

# %%
def area(radius):    return math.pi*radius**2

# %%
area(2)
# Out:
# 12.566370614359172

# %%
def absolute_value(x):    if x<0:        return -x    else:        return x

# %%
absolute_value(3)
# Out:
# 3

# %%
absolute_value(-3)
# Out:
# 3

# %%
def absolute_value(x):    if x<0:        return -x    if x>0:        return x

# %%
absolute_value(-1)
# Out:
# 1

# %%
absolute_value(0)

# %%
print absolute_value(0)
# Out:
# None

# %%
def compare(x,y):    if x>y:        return 1    if x==y:        return 0    if x<y:        return -1    #Exercise 6.1

# %%
compare(1,2)
# Out:
# -1

# %%
compare(5,1)
# Out:
# 1

# %%
compare(16,4**2)
# Out:
# 0

# %%
def distance (x1,y1,x2,y2):    dx=x2-x1    dy=y2-y1    dsquared=dx**2 + dy**2    result=math.sqrt(dsquared)    return result

# %%
distance(1,2,4,6)
# Out:
# 5.0

# %%
def hypotenuse(len1,len2):    asqr=len1**2    bsqr=len2**2    print 'a squared is ', asqr    print 'b squared is ', bsqr    #Starting on Exercise 6.2

# %%
hypotenuse(3,4)
# Out:
# a squared is  9b squared is  16

# %%
def hypotenuse(len1,len2):    asqr=len1**2    bsqr=len2**2    csqr=asqr+bsqr    print 'The length squared of the hypotenuse is ', csqr, '.'

# %%
hypotenuse (3,4)
# Out:
# The length squared of the hypotenuse is  25 .

# %%
def hypotenuse(len1,len2):    asqr=len1**2    bsqr=len2**2    csqr=asqr+bsqr    result=math.sqrt(csqr)    return result

# %%
hypotenuse (3,4)
# Out:
# 5.0

# %%
print 'Finished exercise 6.2!'
# Out:
# Finished exercise 6.2!

# %%
def circle_area(xc,yc,xp,yp):    radius=distance(xc,yc,xp,yp)    result=area(radius)    return result

# %%
circle_area(0,0,0,1)
# Out:
# 3.141592653589793

# %%
def circle_area(xc,yc,xp,yp):    return area(distance(xc,yc,xp,yp))

# %%
circle_area(0,0,0,1)
# Out:
# 3.141592653589793

# %%
def is_divisible(x,y):    if x%y ==0:        return True    else:        return False

# %%
is_divisible(2,4)
# Out:
# False

# %%
is_divisible(4,2)
# Out:
# True

# %%
def is_divisible(x,y):    return x%y==0

# %%
is_divisible(4,2)
# Out:
# True

# %%
is_divisible(2,4)
# Out:
# False

# %%
def factorial(n):    if n==0:        return 1    else:        recurse=factorial(n-1)        result=n*recurse        return result

# %%
factorial(1)
# Out:
# 1

# %%
factorial(0)
# Out:
# 1

# %%
factorial(2)
# Out:
# 2

# %%
factorial(3)
# Out:
# 6

# %%
def fibonacci(n):    if n==0:        return 0    elif n==1:        return 1    else:        return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(4)
# Out:
# 3

# %%
factorial(1.5)
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">RuntimeError</span>                              Traceback (most recent call last)
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-65-e28385ff5339&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansired"> </span>factorial<span class="ansiblue">(</span><span class="ansicyan">1.5</span><span class="ansiblue">)</span><span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# ...
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansired">         </span>recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
# <span class="ansigreen">      6</span>         result<span class="ansiblue">=</span>n<span class="ansiblue">*</span>recurse<span class="ansiblue"></span>
# <span class="ansigreen">      7</span>         <span class="ansigreen">return</span> result<span class="ansiblue"></span>
#
# <span class="ansigreen">/Users/RayRay/PHYS200/&lt;ipython-input-57-db644817e9a5&gt;</span> in <span class="ansicyan">factorial</span><span class="ansiblue">(n)</span>
# <span class="ansigreen">      1</span> <span class="ansigreen">def</span> factorial<span class="ansiblue">(</span>n<span class="ansiblue">)</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansired">     </span><span class="ansigreen">if</span> n<span class="ansiblue">==</span><span class="ansicyan">0</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">      3</span>         <span class="ansigreen">return</span> <span class="ansicyan">1</span><span class="ansiblue"></span>
# <span class="ansigreen">      4</span>     <span class="ansigreen">else</span><span class="ansiblue">:</span><span class="ansiblue"></span>
# <span class="ansigreen">      5</span>         recurse<span class="ansiblue">=</span>factorial<span class="ansiblue">(</span>n<span class="ansiblue">-</span><span class="ansicyan">1</span><span class="ansiblue">)</span><span class="ansiblue"></span>
#
# <span class="ansired">RuntimeError</span>: maximum recursion depth exceeded in cmp

# %%
def factorial(n):    if not isinstance(n, int):        print 'Factorial is only defined for integers.'        return None    elif n<0:        print 'Factorial is not defined for negative integers.'        return None    elif n==0:        return 1    else:        return n*factorial(n-1)

# %%
factorial(1.5)
# Out:
# Factorial is only defined for integers.

# %%
factorial(-1.2)
# Out:
# Factorial is only defined for integers.

# %%
factorial(-12)
# Out:
# Factorial is not defined for negative integers.

# %%
def ack(m,n):    """The Ackermann Function for exercise 6.5"""    if m==0:        return n+1    if m>0 and n==0:        return ack(m-1,1)    if m>0 and n>0:        return ack(m-1,ack(m,n-1))

# %%
ack(3,4)
# Out:
# 125

# %%
def first(word):	return word[0]	def last(word):	return word[-1]	def middle(word):	return word[1:-1]
# Out:
# &apos;h&apos;

# %%
def first(word):	return word[0]	def last(word):	return word[-1]	def middle(word):	return word[1:-1]	def is_palindrome(word):    if len(word)<3:        return False    elif len(word)==3 and first(word)==last(word):        return True    elif len(word)==3 and first(word)!=last(word):        return False    elif first(word)==last(word):        return is_palindrome(middle(word))    else:        return False

# %%
is_palindrome('car')
# Out:
# False

# %%
is_palindrome('road')
# Out:
# False

# %%
is_palindrome('racecar')
# Out:
# True
